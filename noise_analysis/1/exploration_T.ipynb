# %%
import xarray as xr 
import numpy as np 
import matplotlib.pyplot as plt

# %%
graph_no_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/graph_no_d_f/epoch1/2020/combined_rmse_0000_0731_006h_240h_graph_no_d_f.nc')
graph_no1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/1/T/member1/combined_rmse_0000_0015_006h_240h_graph_no_ens.nc')
graph_no2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/1/T/member2/combined_rmse_0000_0015_006h_240h_graph_no_ens.nc')
graph_no3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/1/T/member3/combined_rmse_0000_0015_006h_240h_graph_no_ens.nc')

graph_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/graph_d_fine/epoch3/2020/combined_rmse_0000_0731_006h_240h_graph_d_f.nc')
graph_1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/1/T/member1/combined_rmse_0000_0015_006h_240h_graph_ens.nc')
graph_2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/1/T/member2/combined_rmse_0000_0015_006h_240h_graph_ens.nc')
graph_3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/1/T/member3/combined_rmse_0000_0015_006h_240h_graph_ens.nc')

wxformer_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/wxformer/epoch0/2020/combined_rmse_0000_0731_006h_240h_wxformer.nc')
wxformer_1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/1/T/member1/combined_rmse_0000_0015_006h_240h_wxformer_ens.nc')
wxformer_2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/1/T/member2/combined_rmse_0000_0015_006h_240h_wxformer_ens.nc')
wxformer_3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/1/T/member3/combined_rmse_0000_0015_006h_240h_wxformer_ens.nc')

ifs_2020 = xr.open_dataset("/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/IFS/IFS_2020_combined_rmse_000_731_006h_240h_IFS.nc")

# %%
var_name = 'T500'
idx_tuple = None, 16

# %%
ifs_2020[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.37130043, 0.4194755 , 0.43883213, 0.49647117, 0.52698994,
#        0.59450644, 0.63388044, 0.7082421 , 0.7628275 , 0.84489477,
#        0.90938246, 0.9971234 , 1.0700213 , 1.1558831 , 1.2338518 ,
#        1.3181938 , 1.4027141 , 1.4903147 , 1.5683618 , 1.6565539 ,
#        1.7357401 , 1.8290172 , 1.9207237 , 2.0223544 , 2.120868  ,
#        2.2263923 , 2.3236742 , 2.4216716 , 2.506236  , 2.5993254 ,
#        2.6925886 , 2.7812638 , 2.8712888 , 2.9673321 , 3.0599232 ,
#        3.1532347 , 3.236851  , 3.3112109 , 3.3862855 , 3.4718604 ],
#       dtype=float32)
# Coordinates:
#     level    float32 4B ...
# Dimensions without coordinates: time

# %%
graph_no_2020[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.25313988, 0.37401727, 0.4227128 , 0.5039644 , 0.5554799 ,
#        0.63113755, 0.68660325, 0.76196665, 0.8246021 , 0.9029843 ,
#        0.9714559 , 1.0483843 , 1.122918  , 1.1998451 , 1.2755142 ,
#        1.3486123 , 1.4240079 , 1.4973576 , 1.5758963 , 1.6496376 ,
#        1.7232697 , 1.7902473 , 1.8579832 , 1.92274   , 1.9860275 ,
#        2.0454695 , 2.1096964 , 2.1768866 , 2.2458096 , 2.3157594 ,
#        2.3774886 , 2.4266317 , 2.4753194 , 2.5171213 , 2.565733  ,
#        2.6156788 , 2.6696591 , 2.721334  , 2.773447  , 2.823101  ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_no1[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.2531399 , 0.3740173 , 0.42271283, 0.5039643 , 0.5554797 ,
#        0.63113743, 0.68660337, 0.76196647, 0.8246018 , 0.90298414,
#        0.971456  , 1.0483868 , 1.1229222 , 1.1998478 , 1.2755536 ,
#        1.3486742 , 1.4240336 , 1.4972801 , 1.5758615 , 1.6495838 ,
#        1.7232347 , 1.7901514 , 1.8581016 , 1.9228531 , 1.9861741 ,
#        2.0455203 , 2.1092758 , 2.1768773 , 2.2455115 , 2.314969  ,
#        2.3773553 , 2.4279897 , 2.476539  , 2.5193183 , 2.5674474 ,
#        2.6179063 , 2.671823  , 2.7226694 , 2.775104  , 2.8235664 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_no2[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.25313994, 0.37401733, 0.42271277, 0.5039643 , 0.5554799 ,
#        0.63113755, 0.6866033 , 0.7619665 , 0.8246018 , 0.90298414,
#        0.97145563, 1.0483842 , 1.122922  , 1.1998595 , 1.2755007 ,
#        1.3486025 , 1.4239626 , 1.49726   , 1.5757694 , 1.6494436 ,
#        1.723038  , 1.7900394 , 1.8578349 , 1.9227777 , 1.9860586 ,
#        2.0454266 , 2.109177  , 2.1760757 , 2.244839  , 2.3134801 ,
#        2.3756645 , 2.4254165 , 2.4735115 , 2.514692  , 2.563585  ,
#        2.6131682 , 2.6669908 , 2.7174811 , 2.7689102 , 2.8158822 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_2020[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.25144395, 0.36980513, 0.4170053 , 0.4991344 , 0.5504235 ,
#        0.6257787 , 0.67945045, 0.75395143, 0.8144968 , 0.89372814,
#        0.96455276, 1.0482337 , 1.127575  , 1.2093649 , 1.283679  ,
#        1.3593118 , 1.4328163 , 1.5046253 , 1.5782738 , 1.6472449 ,
#        1.7179319 , 1.7846    , 1.850269  , 1.9202353 , 1.9851677 ,
#        2.0556889 , 2.1221209 , 2.1951559 , 2.2603478 , 2.3301017 ,
#        2.3874254 , 2.441865  , 2.4867067 , 2.5329447 , 2.5724604 ,
#        2.6256702 , 2.6761718 , 2.740612  , 2.7940822 , 2.8565936 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
# ifs_2020[var_name].isel(days=slice(None, 16)).mean('days')
graph_1[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.26825288, 0.4150373 , 0.5032615 , 0.6231146 , 0.71855956,
#        0.8302404 , 0.9225181 , 1.0267876 , 1.1211318 , 1.2265834 ,
#        1.3247808 , 1.4299397 , 1.5311663 , 1.6320201 , 1.7251074 ,
#        1.8187926 , 1.909308  , 1.9976543 , 2.0869355 , 2.172723  ,
#        2.2579691 , 2.340777  , 2.4188418 , 2.503197  , 2.5781572 ,
#        2.6609323 , 2.7355576 , 2.8193898 , 2.8922021 , 2.971375  ,
#        3.0369186 , 3.1020913 , 3.1550899 , 3.213056  , 3.2603292 ,
#        3.321717  , 3.3756118 , 3.4465327 , 3.5019681 , 3.5704718 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_2[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.2565701 , 0.38460776, 0.4464686 , 0.5422437 , 0.6099444 ,
#        0.69810665, 0.7651698 , 0.8489856 , 0.9214233 , 1.0094486 ,
#        1.090075  , 1.181227  , 1.26879   , 1.3577379 , 1.4389184 ,
#        1.521779  , 1.6024636 , 1.6814836 , 1.7621726 , 1.8394989 ,
#        1.9172499 , 1.9922224 , 2.063703  , 2.1418035 , 2.21203   ,
#        2.2896817 , 2.360516  , 2.4407501 , 2.5094452 , 2.5852947 ,
#        2.6465871 , 2.706599  , 2.7555552 , 2.8080459 , 2.8501728 ,
#        2.9077818 , 2.958622  , 3.027345  , 3.0811508 , 3.147588  ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_3[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.27663437, 0.43617806, 0.5413655 , 0.6766026 , 0.7891741 ,
#        0.9157501 , 1.0236887 , 1.1412293 , 1.2492889 , 1.3661653 ,
#        1.475658  , 1.5902358 , 1.7005184 , 1.8093989 , 1.9100986 ,
#        2.0108435 , 2.1083453 , 2.202943  , 2.2973943 , 2.3890374 ,
#        2.4793096 , 2.5670433 , 2.6492589 , 2.7378027 , 2.8164375 ,
#        2.9026122 , 2.9794705 , 3.0662963 , 3.141793  , 3.2239547 ,
#        3.2907958 , 3.3586223 , 3.4147024 , 3.4762344 , 3.5258098 ,
#        3.5901337 , 3.6453645 , 3.7182348 , 3.7744148 , 3.8461156 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_2020[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.32236844, 0.43781808, 0.48743582, 0.5652386 , 0.608222  ,
#        0.6776481 , 0.7275626 , 0.79886913, 0.8616794 , 0.9409139 ,
#        1.0155302 , 1.0984826 , 1.1813205 , 1.2683961 , 1.3559264 ,
#        1.4450924 , 1.5375359 , 1.6286628 , 1.724917  , 1.8223207 ,
#        1.9239545 , 2.023772  , 2.1228702 , 2.218003  , 2.3058298 ,
#        2.3914878 , 2.4734592 , 2.5534153 , 2.6297946 , 2.7028966 ,
#        2.7752476 , 2.837878  , 2.907547  , 2.9676733 , 3.0353873 ,
#        3.0897593 , 3.1530428 , 3.2020075 , 3.2613773 , 3.3062    ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_1[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([2.3529222, 2.8296912, 2.8853033, 2.8404124, 2.7791505, 2.7323432,
#        2.6812692, 2.6522417, 2.618035 , 2.612637 , 2.5986552, 2.6131659,
#        2.6131594, 2.6379747, 2.644926 , 2.6743817, 2.6856625, 2.7181213,
#        2.7341669, 2.773485 , 2.795959 , 2.8325706, 2.8537908, 2.8852053,
#        2.9019697, 2.9269536, 2.94481  , 2.9677994, 2.9831183, 3.00147  ,
#        3.0185306, 3.0360017, 3.0583577, 3.0815406, 3.1117973, 3.141076 ,
#        3.1788397, 3.2141385, 3.2598982, 3.3019083], dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_2[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([1.4166217, 1.7264775, 1.770936 , 1.7620988, 1.7416329, 1.7433258,
#        1.7383692, 1.7607272, 1.7757291, 1.8239019, 1.8632613, 1.9316913,
#        1.9876939, 2.0653503, 2.1279402, 2.206707 , 2.269405 , 2.3455098,
#        2.408118 , 2.4848194, 2.5480134, 2.6164465, 2.6742723, 2.7338405,
#        2.7834277, 2.8318315, 2.8776827, 2.918584 , 2.957097 , 2.9903958,
#        3.0266874, 3.0550086, 3.0922801, 3.1223211, 3.1628406, 3.1954484,
#        3.2398891, 3.2758734, 3.3254807, 3.3667297], dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_3[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([2.854556 , 3.4100368, 3.4737468, 3.4125195, 3.3308606, 3.256927 ,
#        3.183297 , 3.12628  , 3.0688293, 3.0339942, 2.9948554, 2.9784524,
#        2.9508805, 2.9447808, 2.9241729, 2.9243376, 2.9097738, 2.9160972,
#        2.9084182, 2.9256732, 2.9276614, 2.9469042, 2.95048  , 2.9677577,
#        2.9680207, 2.981311 , 2.9838824, 2.9979343, 2.9996707, 3.0101488,
#        3.0154185, 3.0271697, 3.0392787, 3.05725  , 3.0782285, 3.1031687,
#        3.1324897, 3.1638331, 3.202405 , 3.241972 ], dtype=float32)
# Dimensions without coordinates: time

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# var_name = 'V500'
idx_tuple = None, None 

plt.plot(x, graph_2020[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph')
plt.plot(x, graph_1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 1')
plt.plot(x, graph_2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 2')
plt.plot(x, graph_3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# var_name = 'V500'
idx_tuple = None, None 

plt.plot(x, graph_no_2020[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no')
plt.plot(x, graph_no1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 1')
plt.plot(x, graph_no2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 2')
plt.plot(x, graph_no3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# var_name = 'V500'
idx_tuple = None, None 

plt.plot(x, wxformer_2020[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer')
plt.plot(x, wxformer_1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 1')
plt.plot(x, wxformer_2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 2')
plt.plot(x, wxformer_3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();
