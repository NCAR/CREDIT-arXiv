# %%
import xarray as xr 
import numpy as np 
import matplotlib.pyplot as plt

# %%
graph_no_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/graph_no_d_f/epoch1/2020/combined_rmse_0000_0731_006h_240h_graph_no_d_f.nc')
graph_no1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/1/U/member1/combined_rmse_0000_0015_006h_240h_graph_no_ens.nc')
graph_no2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/1/U/member2/combined_rmse_0000_0015_006h_240h_graph_no_ens.nc')
graph_no3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/1/U/member3/combined_rmse_0000_0015_006h_240h_graph_no_ens.nc')

graph_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/graph_d_fine/epoch3/2020/combined_rmse_0000_0731_006h_240h_graph_d_f.nc')
graph_1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/1/U/member1/combined_rmse_0000_0015_006h_240h_graph_ens.nc')
graph_2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/1/U/member2/combined_rmse_0000_0015_006h_240h_graph_ens.nc')
graph_3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/1/U/member3/combined_rmse_0000_0015_006h_240h_graph_ens.nc')

wxformer_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/wxformer/epoch0/2020/combined_rmse_0000_0731_006h_240h_wxformer.nc')
wxformer_1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/1/U/member1/combined_rmse_0000_0015_006h_240h_wxformer_ens.nc')
wxformer_2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/1/U/member2/combined_rmse_0000_0015_006h_240h_wxformer_ens.nc')
wxformer_3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/1/U/member3/combined_rmse_0000_0015_006h_240h_wxformer_ens.nc')

ifs_2020 = xr.open_dataset("/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/IFS/IFS_2020_combined_rmse_000_731_006h_240h_IFS.nc")

# %%
var_name = 'T500'
idx_tuple = None, 16

# %%
ifs_2020[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.37130043, 0.4194755 , 0.43883213, 0.49647117, 0.52698994,
#        0.59450644, 0.63388044, 0.7082421 , 0.7628275 , 0.84489477,
#        0.90938246, 0.9971234 , 1.0700213 , 1.1558831 , 1.2338518 ,
#        1.3181938 , 1.4027141 , 1.4903147 , 1.5683618 , 1.6565539 ,
#        1.7357401 , 1.8290172 , 1.9207237 , 2.0223544 , 2.120868  ,
#        2.2263923 , 2.3236742 , 2.4216716 , 2.506236  , 2.5993254 ,
#        2.6925886 , 2.7812638 , 2.8712888 , 2.9673321 , 3.0599232 ,
#        3.1532347 , 3.236851  , 3.3112109 , 3.3862855 , 3.4718604 ],
#       dtype=float32)
# Coordinates:
#     level    float32 4B ...
# Dimensions without coordinates: time

# %%
graph_no_2020[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.25313988, 0.37401727, 0.4227128 , 0.5039644 , 0.5554799 ,
#        0.63113755, 0.68660325, 0.76196665, 0.8246021 , 0.9029843 ,
#        0.9714559 , 1.0483843 , 1.122918  , 1.1998451 , 1.2755142 ,
#        1.3486123 , 1.4240079 , 1.4973576 , 1.5758963 , 1.6496376 ,
#        1.7232697 , 1.7902473 , 1.8579832 , 1.92274   , 1.9860275 ,
#        2.0454695 , 2.1096964 , 2.1768866 , 2.2458096 , 2.3157594 ,
#        2.3774886 , 2.4266317 , 2.4753194 , 2.5171213 , 2.565733  ,
#        2.6156788 , 2.6696591 , 2.721334  , 2.773447  , 2.823101  ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_no1[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.25313988, 0.37401727, 0.42271283, 0.5039643 , 0.5554799 ,
#        0.63113755, 0.6866033 , 0.7619665 , 0.8246019 , 0.90298426,
#        0.9714561 , 1.0483884 , 1.122918  , 1.19985   , 1.2754507 ,
#        1.3486221 , 1.424052  , 1.4973513 , 1.575773  , 1.649495  ,
#        1.7231385 , 1.7901993 , 1.8581593 , 1.922873  , 1.9860795 ,
#        2.0455205 , 2.1096969 , 2.1768653 , 2.2455516 , 2.3140795 ,
#        2.375605  , 2.4253285 , 2.4736016 , 2.5158665 , 2.56472   ,
#        2.614365  , 2.668228  , 2.72063   , 2.7723274 , 2.8186288 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_no2[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.25313988, 0.3740173 , 0.42271274, 0.50396436, 0.55547976,
#        0.63113755, 0.68660325, 0.7619666 , 0.8246019 , 0.90298396,
#        0.97145545, 1.0483832 , 1.1229213 , 1.1998488 , 1.2754875 ,
#        1.3486177 , 1.4240603 , 1.4974529 , 1.5759959 , 1.6495917 ,
#        1.7231504 , 1.790041  , 1.8580034 , 1.9228072 , 1.9861382 ,
#        2.0454059 , 2.1093013 , 2.1763678 , 2.2447853 , 2.313046  ,
#        2.3740227 , 2.423701  , 2.471665  , 2.513193  , 2.5623372 ,
#        2.6129727 , 2.6663961 , 2.7200434 , 2.772195  , 2.8219151 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_2020[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.25144395, 0.36980513, 0.4170053 , 0.4991344 , 0.5504235 ,
#        0.6257787 , 0.67945045, 0.75395143, 0.8144968 , 0.89372814,
#        0.96455276, 1.0482337 , 1.127575  , 1.2093649 , 1.283679  ,
#        1.3593118 , 1.4328163 , 1.5046253 , 1.5782738 , 1.6472449 ,
#        1.7179319 , 1.7846    , 1.850269  , 1.9202353 , 1.9851677 ,
#        2.0556889 , 2.1221209 , 2.1951559 , 2.2603478 , 2.3301017 ,
#        2.3874254 , 2.441865  , 2.4867067 , 2.5329447 , 2.5724604 ,
#        2.6256702 , 2.6761718 , 2.740612  , 2.7940822 , 2.8565936 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
# ifs_2020[var_name].isel(days=slice(None, 16)).mean('days')
graph_1[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.38305148, 0.63534266, 0.81180274, 0.97408813, 1.0914714 ,
#        1.1990185 , 1.276928  , 1.3515655 , 1.4028245 , 1.4560183 ,
#        1.4959731 , 1.5405642 , 1.5787146 , 1.6184866 , 1.6531478 ,
#        1.6889533 , 1.724576  , 1.7606671 , 1.8003728 , 1.8377695 ,
#        1.8796197 , 1.9205183 , 1.9646664 , 2.0137134 , 2.0632184 ,
#        2.118461  , 2.17379   , 2.2352498 , 2.2920926 , 2.3530316 ,
#        2.4049926 , 2.4543083 , 2.4950287 , 2.5373497 , 2.5744095 ,
#        2.625165  , 2.6742098 , 2.736689  , 2.7901804 , 2.8522363 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_2[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.30770692, 0.48599744, 0.5947835 , 0.7128909 , 0.7948208 ,
#        0.8832751 , 0.94787574, 1.021008  , 1.0756074 , 1.1406368 ,
#        1.1954209 , 1.259612  , 1.3189298 , 1.3810078 , 1.4372671 ,
#        1.4950315 , 1.5517023 , 1.6082004 , 1.6670755 , 1.7223754 ,
#        1.7810396 , 1.8368925 , 1.8935755 , 1.9550102 , 2.0145688 ,
#        2.0788662 , 2.141763  , 2.2105293 , 2.2722576 , 2.3384147 ,
#        2.393681  , 2.4453967 , 2.488316  , 2.5330079 , 2.5717251 ,
#        2.6239712 , 2.67473   , 2.7385044 , 2.7927175 , 2.8557072 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_3[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.42835662, 0.72296536, 0.9363643 , 1.1242759 , 1.2618852 ,
#        1.3817348 , 1.468177  , 1.5455261 , 1.5965761 , 1.6452061 ,
#        1.6785839 , 1.7138032 , 1.7413032 , 1.7693232 , 1.7919481 ,
#        1.8154588 , 1.8386228 , 1.8630419 , 1.8909342 , 1.9176826 ,
#        1.9496164 , 1.9814147 , 2.017453  , 2.0589466 , 2.102243  ,
#        2.1512992 , 2.2009158 , 2.2573931 , 2.3101354 , 2.3675826 ,
#        2.416311  , 2.4630535 , 2.501381  , 2.5417087 , 2.5778856 ,
#        2.627507  , 2.67672   , 2.7381191 , 2.7917755 , 2.8532934 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_2020[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.32236844, 0.43781808, 0.48743582, 0.5652386 , 0.608222  ,
#        0.6776481 , 0.7275626 , 0.79886913, 0.8616794 , 0.9409139 ,
#        1.0155302 , 1.0984826 , 1.1813205 , 1.2683961 , 1.3559264 ,
#        1.4450924 , 1.5375359 , 1.6286628 , 1.724917  , 1.8223207 ,
#        1.9239545 , 2.023772  , 2.1228702 , 2.218003  , 2.3058298 ,
#        2.3914878 , 2.4734592 , 2.5534153 , 2.6297946 , 2.7028966 ,
#        2.7752476 , 2.837878  , 2.907547  , 2.9676733 , 3.0353873 ,
#        3.0897593 , 3.1530428 , 3.2020075 , 3.2613773 , 3.3062    ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_1[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.8224617, 1.2501494, 1.5133674, 1.6975933, 1.8655373, 1.9907331,
#        2.1159086, 2.216709 , 2.332766 , 2.4203281, 2.524476 , 2.6026063,
#        2.695459 , 2.764683 , 2.8483331, 2.9063632, 2.9820533, 3.0311284,
#        3.097523 , 3.1397226, 3.1967225, 3.2283394, 3.2768211, 3.3081493,
#        3.3559532, 3.3857098, 3.4304295, 3.452931 , 3.487949 , 3.4999175,
#        3.5239127, 3.5294082, 3.546816 , 3.5477185, 3.5576105, 3.557172 ,
#        3.5707276, 3.5776277, 3.5927765, 3.6025138], dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_2[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.57664967, 0.8673159 , 1.056723  , 1.210325  , 1.3385072 ,
#        1.4420863 , 1.5401546 , 1.6298252 , 1.7262998 , 1.8089705 ,
#        1.9010946 , 1.9781175 , 2.0663297 , 2.1405299 , 2.2271895 ,
#        2.296191  , 2.381229  , 2.4452777 , 2.5255182 , 2.584687  ,
#        2.6552944 , 2.7006366 , 2.7551632 , 2.7891674 , 2.8335116 ,
#        2.8632908 , 2.9095664 , 2.9439793 , 2.9885092 , 3.0183911 ,
#        3.057626  , 3.082552  , 3.1206653 , 3.1508265 , 3.1905103 ,
#        3.2220678 , 3.2590942 , 3.2895823 , 3.3241532 , 3.356721  ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_3[var_name].mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.9402361, 1.430175 , 1.7255256, 1.9188017, 2.0992255, 2.229691 ,
#        2.3630638, 2.4647946, 2.5859625, 2.6724863, 2.7775779, 2.8514218,
#        2.9416547, 3.0042357, 3.0826037, 3.132972 , 3.2032022, 3.2462223,
#        3.306487 , 3.341689 , 3.395869 , 3.42545  , 3.474471 , 3.5035312,
#        3.5508335, 3.5774474, 3.6203902, 3.6370106, 3.6664324, 3.6704237,
#        3.6880507, 3.685078 , 3.694481 , 3.6872957, 3.692427 , 3.6901708,
#        3.7054822, 3.7106476, 3.7235928, 3.7281413], dtype=float32)
# Dimensions without coordinates: time

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# var_name = 'V500'
idx_tuple = None, None 

plt.plot(x, graph_2020[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph')
plt.plot(x, graph_1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 1')
plt.plot(x, graph_2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 2')
plt.plot(x, graph_3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# var_name = 'V500'
idx_tuple = None, None 

plt.plot(x, graph_no_2020[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no')
plt.plot(x, graph_no1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 1')
plt.plot(x, graph_no2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 2')
plt.plot(x, graph_no3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# var_name = 'V500'
idx_tuple = None, None 

plt.plot(x, wxformer_2020[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer')
plt.plot(x, wxformer_1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 1')
plt.plot(x, wxformer_2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 2')
plt.plot(x, wxformer_3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();
