# %%
import xarray as xr 
import numpy as np 
import matplotlib.pyplot as plt

# %%
graph_no_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/graph_no_d_f/epoch1/2020/combined_rmse_0000_0731_006h_240h_graph_no_d_f.nc')
graph_no1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/1/Q/member1/combined_rmse_0000_0015_006h_240h_graph_no_ens.nc')
graph_no2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/1/Q/member2/combined_rmse_0000_0015_006h_240h_graph_no_ens.nc')
graph_no3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/1/Q/member3/combined_rmse_0000_0015_006h_240h_graph_no_ens.nc')

graph_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/graph_d_fine/epoch3/2020/combined_rmse_0000_0731_006h_240h_graph_d_f.nc')
graph_1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/1/Q/member1/combined_rmse_0000_0015_006h_240h_graph_ens.nc')
graph_2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/1/Q/member2/combined_rmse_0000_0015_006h_240h_graph_ens.nc')
graph_3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/1/Q/member3/combined_rmse_0000_0015_006h_240h_graph_ens.nc')

wxformer_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/wxformer/epoch0/2020/combined_rmse_0000_0731_006h_240h_wxformer.nc')
wxformer_1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/1/Q/member1/combined_rmse_0000_0015_006h_240h_wxformer_ens.nc')
wxformer_2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/1/Q/member2/combined_rmse_0000_0015_006h_240h_wxformer_ens.nc')
wxformer_3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/1/Q/member3/combined_rmse_0000_0015_006h_240h_wxformer_ens.nc')

ifs_2020 = xr.open_dataset("/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/IFS/IFS_2020_combined_rmse_000_731_006h_240h_IFS.nc")

# %%
var_name = 'Q500'
idx_tuple = None, 16

# %%
ifs_2020[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Q500' (time: 40)> Size: 160B
# array([0.00027419, 0.00030977, 0.00033069, 0.00036985, 0.00039044,
#        0.00042535, 0.00043915, 0.0004695 , 0.00048284, 0.0005102 ,
#        0.00052217, 0.00054665, 0.00055756, 0.00058083, 0.00059259,
#        0.00061528, 0.00062658, 0.0006484 , 0.00065862, 0.00068154,
#        0.00069442, 0.00071748, 0.00072954, 0.00075323, 0.0007691 ,
#        0.0007923 , 0.00080742, 0.000827  , 0.00083798, 0.00085645,
#        0.00087   , 0.00088988, 0.00090271, 0.0009203 , 0.00093102,
#        0.00094434, 0.00095142, 0.00096407, 0.00096963, 0.00098316],
#       dtype=float32)
# Coordinates:
#     level    float32 4B ...
# Dimensions without coordinates: time

# %%
graph_no_2020[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Q500' (time: 40)> Size: 160B
# array([0.00012914, 0.00021507, 0.00025576, 0.00030321, 0.00032935,
#        0.00036088, 0.00037827, 0.00040387, 0.00041986, 0.00044345,
#        0.00045934, 0.00048084, 0.00049484, 0.00051465, 0.00052769,
#        0.00054549, 0.00055643, 0.00057279, 0.00058188, 0.00059635,
#        0.00060401, 0.00061811, 0.00062653, 0.00064085, 0.00064913,
#        0.00066227, 0.00067113, 0.00068505, 0.00069466, 0.00070713,
#        0.00071598, 0.00072965, 0.00073927, 0.00075313, 0.00076276,
#        0.0007779 , 0.00078622, 0.00079883, 0.00080635, 0.00081791],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_no1[var_name].mean('days')
# Out:
# <xarray.DataArray 'Q500' (time: 40)> Size: 160B
# array([0.00012914, 0.00021507, 0.00025576, 0.00030321, 0.00032935,
#        0.00036088, 0.00037827, 0.00040387, 0.00041986, 0.00044345,
#        0.00045934, 0.00048084, 0.00049484, 0.00051465, 0.00052769,
#        0.00054549, 0.00055642, 0.0005728 , 0.00058188, 0.00059635,
#        0.00060401, 0.0006181 , 0.00062652, 0.00064078, 0.00064907,
#        0.00066229, 0.00067124, 0.00068523, 0.00069483, 0.00070714,
#        0.00071588, 0.00072967, 0.00073925, 0.0007534 , 0.0007632 ,
#        0.00077819, 0.00078622, 0.00079874, 0.00080614, 0.00081775],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_no2[var_name].mean('days')
# Out:
# <xarray.DataArray 'Q500' (time: 40)> Size: 160B
# array([0.00012914, 0.00021507, 0.00025576, 0.00030321, 0.00032935,
#        0.00036088, 0.00037827, 0.00040387, 0.00041986, 0.00044345,
#        0.00045934, 0.00048084, 0.00049484, 0.00051465, 0.0005277 ,
#        0.00054549, 0.00055643, 0.00057278, 0.00058187, 0.00059637,
#        0.00060404, 0.00061811, 0.00062653, 0.0006408 , 0.00064907,
#        0.00066224, 0.00067111, 0.00068503, 0.00069457, 0.00070697,
#        0.00071567, 0.00072938, 0.00073901, 0.0007532 , 0.00076293,
#        0.00077806, 0.00078632, 0.00079899, 0.00080653, 0.00081811],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_2020[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Q500' (time: 40)> Size: 160B
# array([0.00012896, 0.00021388, 0.00025378, 0.00030193, 0.00032822,
#        0.00036053, 0.00037849, 0.00040524, 0.00042111, 0.00044492,
#        0.00046107, 0.0004835 , 0.00049787, 0.00051921, 0.00053272,
#        0.00055186, 0.00056344, 0.00058111, 0.00059032, 0.00060511,
#        0.00061375, 0.00062808, 0.00063717, 0.00065161, 0.00066055,
#        0.00067386, 0.00068335, 0.00069735, 0.00070661, 0.00072022,
#        0.00072874, 0.0007416 , 0.00074973, 0.00076144, 0.00076809,
#        0.00078068, 0.00078584, 0.00079614, 0.00080259, 0.00081492],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
# ifs_2020[var_name].isel(days=slice(None, 16)).mean('days')
graph_1[var_name].mean('days')
# Out:
# <xarray.DataArray 'Q500' (time: 40)> Size: 160B
# array([0.00013132, 0.00021887, 0.00026274, 0.00031407, 0.00034453,
#        0.00037973, 0.00040186, 0.00043102, 0.00045056, 0.00047643,
#        0.00049561, 0.00051948, 0.00053618, 0.0005582 , 0.0005733 ,
#        0.0005924 , 0.00060489, 0.00062169, 0.00063092, 0.00064417,
#        0.00065212, 0.00066432, 0.00067225, 0.00068426, 0.00069196,
#        0.00070264, 0.00071048, 0.00072179, 0.00072954, 0.00074077,
#        0.00074788, 0.00075836, 0.00076523, 0.00077501, 0.00078075,
#        0.00079158, 0.00079596, 0.00080472, 0.00081039, 0.00082144],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_2[var_name].mean('days')
# Out:
# <xarray.DataArray 'Q500' (time: 40)> Size: 160B
# array([0.00012989, 0.0002158 , 0.0002573 , 0.00030665, 0.00033463,
#        0.00036797, 0.00038765, 0.00041523, 0.00043266, 0.00045722,
#        0.00047472, 0.00049768, 0.00051311, 0.00053466, 0.00054893,
#        0.00056796, 0.00057999, 0.00059715, 0.00060635, 0.00062028,
#        0.00062859, 0.00064178, 0.00065035, 0.00066367, 0.00067209,
#        0.00068412, 0.00069291, 0.00070559, 0.00071427, 0.00072674,
#        0.00073467, 0.0007465 , 0.00075421, 0.00076514, 0.00077154,
#        0.00078341, 0.00078836, 0.00079811, 0.00080432, 0.00081606],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_3[var_name].mean('days')
# Out:
# <xarray.DataArray 'Q500' (time: 40)> Size: 160B
# array([0.00013231, 0.00022101, 0.00026651, 0.00031921, 0.00035135,
#        0.00038787, 0.00041163, 0.00044191, 0.00046285, 0.00048963,
#        0.00050991, 0.00053443, 0.00055196, 0.00057433, 0.00059   ,
#        0.00060922, 0.000622  , 0.00063864, 0.00064794, 0.00066084,
#        0.00066866, 0.00068024, 0.00068782, 0.00069911, 0.00070626,
#        0.00071623, 0.00072349, 0.00073382, 0.00074091, 0.00075127,
#        0.00075777, 0.0007674 , 0.00077363, 0.00078267, 0.00078796,
#        0.00079812, 0.00080197, 0.00081017, 0.00081544, 0.00082579],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_2020[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Q500' (time: 40)> Size: 160B
# array([0.00015935, 0.00023877, 0.00027712, 0.00032517, 0.00034959,
#        0.00038226, 0.00039881, 0.00042601, 0.00044198, 0.00046598,
#        0.0004804 , 0.00050336, 0.00051628, 0.00053753, 0.00055092,
#        0.00057192, 0.00058476, 0.00060476, 0.00061758, 0.00063589,
#        0.00064924, 0.00066596, 0.00067863, 0.00069295, 0.00070566,
#        0.0007184 , 0.00073078, 0.00074243, 0.00075482, 0.0007649 ,
#        0.00077709, 0.00078709, 0.00079887, 0.00080746, 0.00081797,
#        0.00082605, 0.00083562, 0.00084256, 0.00085171, 0.00085849],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_1[var_name].mean('days')
# Out:
# <xarray.DataArray 'Q500' (time: 40)> Size: 160B
# array([0.00059484, 0.00070125, 0.00070067, 0.00066478, 0.00063607,
#        0.0006143 , 0.0006008 , 0.00060034, 0.00060295, 0.00061502,
#        0.00062554, 0.0006421 , 0.00065259, 0.00066673, 0.00067717,
#        0.00069024, 0.00070027, 0.00071361, 0.00072572, 0.00073885,
#        0.00074973, 0.00076153, 0.00077023, 0.00078072, 0.00078846,
#        0.00079763, 0.0008042 , 0.00081364, 0.00082281, 0.00083187,
#        0.00083995, 0.00084939, 0.00085785, 0.00086454, 0.00087216,
#        0.00088065, 0.00088825, 0.00089769, 0.00090641, 0.00091445],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_2[var_name].mean('days')
# Out:
# <xarray.DataArray 'Q500' (time: 40)> Size: 160B
# array([0.00040264, 0.00047183, 0.00047973, 0.00047986, 0.00047883,
#        0.00048524, 0.00048925, 0.00050374, 0.00051493, 0.00053303,
#        0.00054695, 0.00056721, 0.00057998, 0.00059739, 0.00060938,
#        0.00062495, 0.0006359 , 0.00065044, 0.00066101, 0.00067521,
#        0.00068525, 0.00069773, 0.00070561, 0.0007157 , 0.00072275,
#        0.00073212, 0.00073755, 0.00074717, 0.00075481, 0.00076519,
#        0.00077259, 0.00078361, 0.00079183, 0.00080056, 0.00080762,
#        0.00081833, 0.00082567, 0.00083445, 0.00084139, 0.00085043],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_3[var_name].mean('days')
# Out:
# <xarray.DataArray 'Q500' (time: 40)> Size: 160B
# array([0.00068067, 0.0008103 , 0.000807  , 0.00075575, 0.0007146 ,
#        0.00068043, 0.00065856, 0.00065078, 0.00064866, 0.00065727,
#        0.00066535, 0.00067959, 0.00068814, 0.00070031, 0.0007093 ,
#        0.00072121, 0.00073081, 0.00074388, 0.00075611, 0.00076863,
#        0.00077953, 0.00079097, 0.00079958, 0.00080925, 0.00081632,
#        0.0008248 , 0.00083162, 0.00084092, 0.00085066, 0.00085995,
#        0.00086842, 0.00087736, 0.00088586, 0.00089223, 0.00090071,
#        0.00090976, 0.00091868, 0.0009282 , 0.00093713, 0.00094296],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# var_name = 'V500'
idx_tuple = None, None 

plt.plot(x, graph_2020[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph')
plt.plot(x, graph_1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 1')
plt.plot(x, graph_2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 2')
plt.plot(x, graph_3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# var_name = 'V500'
idx_tuple = None, None 

plt.plot(x, graph_no_2020[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no')
plt.plot(x, graph_no1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 1')
plt.plot(x, graph_no2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 2')
plt.plot(x, graph_no3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# var_name = 'V500'
idx_tuple = None, None 

plt.plot(x, wxformer_2020[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer')
plt.plot(x, wxformer_1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 1')
plt.plot(x, wxformer_2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 2')
plt.plot(x, wxformer_3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();
