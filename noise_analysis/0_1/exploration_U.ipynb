# %%
import xarray as xr 
import numpy as np 
import matplotlib.pyplot as plt

# %%
graph_no_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/graph_no_d_f/epoch1/2020/combined_rmse_0000_0731_006h_240h_graph_no_d_f.nc')
graph_no1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/0_1/U/member1/combined_rmse_0000_0047_006h_240h_graph_no_ens.nc')
graph_no2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/0_1/U/member2/combined_rmse_0000_0047_006h_240h_graph_no_ens.nc')
graph_no3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/0_1/U/member3/combined_rmse_0000_0047_006h_240h_graph_no_ens.nc')

graph_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/graph_d_fine/epoch3/2020/combined_rmse_0000_0731_006h_240h_graph_d_f.nc')
graph_1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/0_1/U/member1/combined_rmse_0000_0047_006h_240h_graph_ens.nc')
graph_2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/0_1/U/member2/combined_rmse_0000_0047_006h_240h_graph_ens.nc')
graph_3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/0_1/U/member3/combined_rmse_0000_0047_006h_240h_graph_ens.nc')

wxformer_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/wxformer/epoch0/2020/combined_rmse_0000_0731_006h_240h_wxformer.nc')
wxformer_1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/0_1/U/member1/combined_rmse_0000_0047_006h_240h_wxformer_ens.nc')
wxformer_2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/0_1/U/member2/combined_rmse_0000_0047_006h_240h_wxformer_ens.nc')
wxformer_3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/0_1/U/member3/combined_rmse_0000_0047_006h_240h_wxformer_ens.nc')

ifs_2020 = xr.open_dataset("/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/IFS/IFS_2020_combined_rmse_000_731_006h_240h_IFS.nc")

# %%
def idx_tuple_fn(i):
    
    return {
        'year': [(0, 16), (270, 286), (392, 408)][i], # May 15 is day 136, July 15 is day 197 
        'parts': [(0, 16), (16, 32), (32, 48)][i] # (0, 16) is for 2020-01-01T00Z to 2020-01-08T12Z; (16, 32) for 2020-05-15T00Z to 2020-05-22T12Z; (32, 48) for 2020-07-15T00Z to 2020-07-22T12Z
    }
    {

    }

var_name = 'Z500'
# idx_tuple = None, 16

idx_dict = idx_tuple_fn(0)
year_idx_tuple = idx_dict['year']
# year_idx_tuple = idx_dict['year']
idx_tuple = idx_dict['parts']

# %%
ifs_2020[var_name].isel(days=slice(*year_idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Z500' (time: 40)> Size: 160B
# array([ 27.91089 ,  39.64224 ,  39.668064,  51.312775,  54.65788 ,
#         66.92332 ,  72.93645 ,  86.47341 ,  94.2816  , 109.14259 ,
#        118.92756 , 135.71193 , 148.88708 , 168.34056 , 183.56384 ,
#        203.83072 , 221.12599 , 243.6073  , 262.8332  , 285.1101  ,
#        303.63165 , 327.3711  , 349.6171  , 375.99097 , 398.41653 ,
#        424.0591  , 446.39276 , 471.78253 , 495.27643 , 522.661   ,
#        548.5681  , 577.7531  , 604.7392  , 633.0886  , 659.8031  ,
#        687.729   , 713.9918  , 739.5045  , 763.34454 , 788.47943 ],
#       dtype=float32)
# Coordinates:
#     level    float32 4B ...
# Dimensions without coordinates: time

# %%
graph_no_2020[var_name].isel(days=slice(*year_idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Z500' (time: 40)> Size: 160B
# array([ 26.952051,  40.33252 ,  46.944633,  59.55971 ,  67.754074,
#         82.44137 ,  92.307655, 106.81617 , 118.147156, 134.2044  ,
#        147.15056 , 164.46024 , 179.37988 , 197.99712 , 213.84845 ,
#        232.95387 , 249.93825 , 269.52484 , 286.8744  , 306.6668  ,
#        323.87982 , 343.55286 , 360.87903 , 379.11462 , 394.69403 ,
#        410.81183 , 425.1335  , 440.42145 , 454.30414 , 469.75186 ,
#        484.07556 , 500.20288 , 515.1691  , 529.932   , 543.3776  ,
#        557.66943 , 570.82007 , 584.2889  , 596.2779  , 608.7633  ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_no1[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Z500' (time: 40)> Size: 160B
# array([ 26.95205 ,  40.332516,  46.944622,  59.559704,  67.754074,
#         82.441345,  92.30761 , 106.816124, 118.14707 , 134.20432 ,
#        147.15039 , 164.46361 , 179.38193 , 197.97949 , 213.85179 ,
#        232.95732 , 249.9541  , 269.54874 , 286.88794 , 306.6722  ,
#        323.86917 , 343.53757 , 360.88034 , 379.1152  , 394.6627  ,
#        410.81024 , 425.06747 , 440.29236 , 454.11792 , 469.49936 ,
#        483.82996 , 500.0348  , 514.9712  , 529.6018  , 543.03235 ,
#        557.4008  , 570.8254  , 584.56995 , 596.6659  , 609.30054 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_no2[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Z500' (time: 40)> Size: 160B
# array([ 26.95205 ,  40.332527,  46.94465 ,  59.559715,  67.754074,
#         82.44136 ,  92.30764 , 106.81613 , 118.14713 , 134.20439 ,
#        147.15045 , 164.46301 , 179.3805  , 197.99223 , 213.85333 ,
#        232.95415 , 249.94608 , 269.53574 , 286.8881  , 306.6751  ,
#        323.88025 , 343.5551  , 360.8715  , 379.06982 , 394.60898 ,
#        410.7488  , 425.00616 , 440.17194 , 454.0757  , 469.37823 ,
#        483.78482 , 500.13364 , 515.1481  , 529.74445 , 543.1415  ,
#        557.6802  , 571.055   , 584.5509  , 596.6963  , 609.16895 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_2020[var_name].isel(days=slice(*year_idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Z500' (time: 40)> Size: 160B
# array([ 27.760822,  41.554276,  48.573532,  60.58345 ,  69.121445,
#         82.70267 ,  92.828316, 106.334335, 118.35167 , 133.77184 ,
#        147.85715 , 164.82088 , 181.39104 , 199.65904 , 216.75401 ,
#        235.14536 , 252.71436 , 271.55988 , 289.32056 , 308.63943 ,
#        327.3451  , 348.11716 , 367.72308 , 388.11752 , 405.9744  ,
#        424.50357 , 440.55286 , 457.6893  , 472.34845 , 488.2405  ,
#        501.83826 , 517.9668  , 532.1704  , 547.83093 , 561.749   ,
#        577.97723 , 592.72    , 608.2952  , 621.4985  , 635.9448  ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
# ifs_2020[var_name].isel(days=slice(None, 16)).mean('days')
graph_1[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Z500' (time: 40)> Size: 160B
# array([ 28.05629 ,  42.99096 ,  50.229797,  63.185123,  71.42652 ,
#         85.48356 ,  94.92927 , 108.5588  , 119.76929 , 135.23996 ,
#        148.54063 , 165.46785 , 181.33008 , 199.64912 , 216.12386 ,
#        234.63712 , 251.71307 , 270.76923 , 288.1053  , 307.66953 ,
#        325.99622 , 346.97498 , 366.13672 , 386.81836 , 404.43625 ,
#        423.25464 , 439.06668 , 456.63135 , 471.07227 , 487.2597  ,
#        500.57666 , 516.8586  , 530.71985 , 546.581   , 560.3447  ,
#        576.7898  , 591.1206  , 606.86304 , 619.8708  , 634.65405 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_2[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Z500' (time: 40)> Size: 160B
# array([ 27.842123,  42.1962  ,  49.199955,  61.689518,  69.95251 ,
#         83.78361 ,  93.45231 , 107.02052 , 118.54087 , 134.00264 ,
#        147.62662 , 164.58923 , 180.76022 , 199.08383 , 215.83871 ,
#        234.32848 , 251.64215 , 270.62665 , 288.1756  , 307.61374 ,
#        326.13574 , 347.11734 , 366.54626 , 387.21594 , 405.00833 ,
#        423.71686 , 439.6695  , 457.12366 , 471.72952 , 487.8262  ,
#        501.2842  , 517.5033  , 531.4956  , 547.3262  , 561.0463  ,
#        577.2157  , 591.5172  , 607.1674  , 620.26685 , 634.7882  ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_3[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Z500' (time: 40)> Size: 160B
# array([ 28.219887,  43.520092,  50.958748,  64.199875,  72.484055,
#         86.677666,  96.03822 , 109.70715 , 120.76811 , 136.23833 ,
#        149.36946 , 166.267   , 181.96288 , 200.27309 , 216.60364 ,
#        235.1445  , 252.09958 , 271.14343 , 288.32797 , 307.86398 ,
#        326.02374 , 347.04352 , 366.16058 , 386.83887 , 404.24536 ,
#        423.19363 , 438.8102  , 456.36765 , 470.70123 , 486.86273 ,
#        500.18307 , 516.6493  , 530.5621  , 546.5331  , 560.20966 ,
#        576.50586 , 590.6353  , 606.3791  , 619.4548  , 634.22577 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_2020[var_name].isel(days=slice(*year_idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Z500' (time: 40)> Size: 160B
# array([ 28.85181 ,  41.647953,  48.35285 ,  60.283237,  68.7289  ,
#         81.72741 ,  92.29732 , 106.779755, 120.13225 , 137.4125  ,
#        153.87181 , 173.92522 , 193.33788 , 215.56526 , 236.09132 ,
#        258.90533 , 280.1528  , 304.00385 , 326.3796  , 350.96313 ,
#        373.28174 , 398.12573 , 420.1456  , 443.9076  , 464.77466 ,
#        488.27554 , 508.2955  , 531.48944 , 550.9717  , 573.9135  ,
#        593.0696  , 615.4651  , 634.7798  , 655.86017 , 674.35736 ,
#        694.41296 , 711.94037 , 730.5752  , 746.2438  , 762.92224 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_1[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Z500' (time: 40)> Size: 160B
# array([ 51.943024,  72.07042 ,  86.67857 ,  93.59897 , 103.57035 ,
#        110.43586 , 120.898026, 130.56187 , 144.02934 , 157.98499 ,
#        174.90625 , 192.75616 , 212.82442 , 233.72482 , 255.16348 ,
#        276.87506 , 298.49628 , 321.15286 , 343.29324 , 365.98886 ,
#        387.33826 , 409.70056 , 430.13144 , 450.95227 , 469.61288 ,
#        489.83173 , 507.5785  , 527.8452  , 545.4543  , 566.0501  ,
#        583.7677  , 604.93506 , 623.70526 , 644.643   , 663.2139  ,
#        683.6964  , 701.56793 , 720.44995 , 736.36456 , 753.43066 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_2[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Z500' (time: 40)> Size: 160B
# array([ 40.05213 ,  55.131756,  66.67665 ,  74.9919  ,  84.8397  ,
#         94.087204, 105.0279  , 116.793   , 130.5436  , 146.04756 ,
#        163.0381  , 181.9772  , 201.96883 , 223.57153 , 244.74207 ,
#        267.0289  , 288.53616 , 311.75467 , 334.01355 , 357.54047 ,
#        379.31302 , 402.7693  , 423.90442 , 445.9907  , 465.62537 ,
#        487.28677 , 506.0523  , 527.6212  , 546.081   , 567.8085  ,
#        586.2116  , 608.0442  , 627.1238  , 648.2534  , 666.854   ,
#        687.2608  , 705.052   , 723.91003 , 739.782   , 756.7569  ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_3[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'Z500' (time: 40)> Size: 160B
# array([ 58.71418 ,  82.00732 ,  98.18458 , 104.757774, 114.74175 ,
#        120.61131 , 130.76218 , 139.4259  , 152.66606 , 165.81755 ,
#        182.61644 , 199.85509 , 219.89226 , 240.38438 , 261.93008 ,
#        283.31207 , 304.99353 , 327.34033 , 349.42865 , 371.68585 ,
#        392.82526 , 414.5955  , 434.6462  , 454.77655 , 472.88834 ,
#        492.27075 , 509.40823 , 528.8815  , 545.9596  , 565.85803 ,
#        583.15424 , 603.8826  , 622.4536  , 643.23596 , 661.78107 ,
#        682.27704 , 700.1797  , 719.0601  , 734.9876  , 752.08527 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# year_idx_tuple = None, 16
plt.plot(x, graph_2020[var_name].isel(days=slice(*year_idx_tuple)).mean(dim='days').values, label='Graph')
plt.plot(x, graph_1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 1')
plt.plot(x, graph_2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 2')
plt.plot(x, graph_3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# var_name = 'V500'
# idx_tuple = None, None 

plt.plot(x, graph_no_2020[var_name].isel(days=slice(*year_idx_tuple)).mean(dim='days').values, label='Graph no')
plt.plot(x, graph_no1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 1')
plt.plot(x, graph_no2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 2')
plt.plot(x, graph_no3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# var_name = 'V500'
# idx_tuple = None, None 

plt.plot(x, wxformer_2020[var_name].isel(days=slice(*year_idx_tuple)).mean(dim='days').values, label='Wxformer')
plt.plot(x, wxformer_1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 1')
plt.plot(x, wxformer_2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 2')
plt.plot(x, wxformer_3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();
