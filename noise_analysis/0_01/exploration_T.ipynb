# %%
import xarray as xr 
import numpy as np 
import matplotlib.pyplot as plt

# %%
graph_no_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/graph_no_d_f/epoch1/2020/combined_rmse_0000_0731_006h_240h_graph_no_d_f.nc')
graph_no1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/0_01/T/member1/combined_rmse_0000_0047_006h_240h_graph_no_ens.nc')
graph_no2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/0_01/T/member2/combined_rmse_0000_0047_006h_240h_graph_no_ens.nc')
graph_no3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_no_ens/0_01/T/member3/combined_rmse_0000_0047_006h_240h_graph_no_ens.nc')


graph_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/graph_d_fine/epoch3/2020/combined_rmse_0000_0731_006h_240h_graph_d_f.nc')
graph_1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/0_01/T/member1/combined_rmse_0000_0047_006h_240h_graph_ens.nc')
graph_2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/0_01/T/member2/combined_rmse_0000_0047_006h_240h_graph_ens.nc')
graph_3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/graph_ens/0_01/T/member3/combined_rmse_0000_0047_006h_240h_graph_ens.nc')

wxformer_2020 = xr.open_dataset('/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/wxformer/epoch0/2020/combined_rmse_0000_0731_006h_240h_wxformer.nc')
wxformer_1 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/0_01/T/member1/combined_rmse_0000_0047_006h_240h_wxformer_ens.nc')
wxformer_2 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/0_01/T/member2/combined_rmse_0000_0047_006h_240h_wxformer_ens.nc')
wxformer_3 = xr.open_dataset('/glade/derecho/scratch/akn7/CREDIT_arXiv/VERIF/wxformer_ens/0_01/T/member3/combined_rmse_0000_0047_006h_240h_wxformer_ens.nc')

ifs_2020 = xr.open_dataset("/glade/campaign/cisl/aiml/akn7/CREDIT_arXiv/VERIF/IFS/IFS_2020_combined_rmse_000_731_006h_240h_IFS.nc")

# %%
def idx_tuple_fn(i):
    
    return {
        'year': [(0, 16), (270, 286), (392, 408)][i], # May 15 is day 136, July 15 is day 197 
        'parts': [(0, 16), (16, 32), (32, 48)][i] # (0, 16) is for 2020-01-01T00Z to 2020-01-08T12Z; (16, 32) for 2020-05-15T00Z to 2020-05-22T12Z; (32, 48) for 2020-07-15T00Z to 2020-07-22T12Z
    }
    {

    }

var_name = 'T500'
# idx_tuple = None, 16

idx_dict = idx_tuple_fn(0)
year_idx_tuple = idx_dict['year']
# year_idx_tuple = idx_dict['year']
idx_tuple = idx_dict['parts']

# %%
ifs_2020[var_name].isel(days=slice(*year_idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.37130043, 0.4194755 , 0.43883213, 0.49647117, 0.52698994,
#        0.59450644, 0.63388044, 0.7082421 , 0.7628275 , 0.84489477,
#        0.90938246, 0.9971234 , 1.0700213 , 1.1558831 , 1.2338518 ,
#        1.3181938 , 1.4027141 , 1.4903147 , 1.5683618 , 1.6565539 ,
#        1.7357401 , 1.8290172 , 1.9207237 , 2.0223544 , 2.120868  ,
#        2.2263923 , 2.3236742 , 2.4216716 , 2.506236  , 2.5993254 ,
#        2.6925886 , 2.7812638 , 2.8712888 , 2.9673321 , 3.0599232 ,
#        3.1532347 , 3.236851  , 3.3112109 , 3.3862855 , 3.4718604 ],
#       dtype=float32)
# Coordinates:
#     level    float32 4B ...
# Dimensions without coordinates: time

# %%
graph_no_2020[var_name].isel(days=slice(*year_idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.25313988, 0.37401727, 0.4227128 , 0.5039644 , 0.5554799 ,
#        0.63113755, 0.68660325, 0.76196665, 0.8246021 , 0.9029843 ,
#        0.9714559 , 1.0483843 , 1.122918  , 1.1998451 , 1.2755142 ,
#        1.3486123 , 1.4240079 , 1.4973576 , 1.5758963 , 1.6496376 ,
#        1.7232697 , 1.7902473 , 1.8579832 , 1.92274   , 1.9860275 ,
#        2.0454695 , 2.1096964 , 2.1768866 , 2.2458096 , 2.3157594 ,
#        2.3774886 , 2.4266317 , 2.4753194 , 2.5171213 , 2.565733  ,
#        2.6156788 , 2.6696591 , 2.721334  , 2.773447  , 2.823101  ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_no1[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.2531399 , 0.37401724, 0.42271283, 0.5039644 , 0.5554798 ,
#        0.63113755, 0.68660337, 0.7619666 , 0.82460207, 0.90298426,
#        0.9714557 , 1.0483838 , 1.1229178 , 1.1998588 , 1.2754976 ,
#        1.3485787 , 1.4239197 , 1.4972504 , 1.5757483 , 1.6493709 ,
#        1.7230263 , 1.7901348 , 1.8580866 , 1.9228858 , 1.9861002 ,
#        2.0454898 , 2.109722  , 2.176817  , 2.2457132 , 2.3139086 ,
#        2.3750806 , 2.424352  , 2.472235  , 2.5133648 , 2.561465  ,
#        2.6100278 , 2.6639557 , 2.7142773 , 2.7649746 , 2.811905  ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_no2[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.2531399 , 0.37401724, 0.42271277, 0.5039643 , 0.5554798 ,
#        0.6311375 , 0.68660325, 0.7619664 , 0.82460177, 0.9029841 ,
#        0.97145617, 1.0483856 , 1.1229206 , 1.1998533 , 1.2754858 ,
#        1.3485785 , 1.4239632 , 1.4972122 , 1.5756981 , 1.6495476 ,
#        1.7232366 , 1.7903428 , 1.8582627 , 1.923043  , 1.9862217 ,
#        2.0454426 , 2.1092594 , 2.1765094 , 2.2448745 , 2.3138425 ,
#        2.3759048 , 2.425948  , 2.474783  , 2.5178344 , 2.5668883 ,
#        2.6179733 , 2.6721714 , 2.7241697 , 2.7765925 , 2.8234947 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_2020[var_name].isel(days=slice(*year_idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.25144395, 0.36980513, 0.4170053 , 0.4991344 , 0.5504235 ,
#        0.6257787 , 0.67945045, 0.75395143, 0.8144968 , 0.89372814,
#        0.96455276, 1.0482337 , 1.127575  , 1.2093649 , 1.283679  ,
#        1.3593118 , 1.4328163 , 1.5046253 , 1.5782738 , 1.6472449 ,
#        1.7179319 , 1.7846    , 1.850269  , 1.9202353 , 1.9851677 ,
#        2.0556889 , 2.1221209 , 2.1951559 , 2.2603478 , 2.3301017 ,
#        2.3874254 , 2.441865  , 2.4867067 , 2.5329447 , 2.5724604 ,
#        2.6256702 , 2.6761718 , 2.740612  , 2.7940822 , 2.8565936 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
# ifs_2020[var_name].isel(days=slice(None, 16)).mean('days')
graph_1[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.25140086, 0.36972183, 0.4168668 , 0.49894685, 0.5501753 ,
#        0.6254563 , 0.6790223 , 0.7534125 , 0.8138788 , 0.8930496 ,
#        0.96383506, 1.0474945 , 1.1268355 , 1.2086334 , 1.282926  ,
#        1.358554  , 1.432169  , 1.504014  , 1.5776954 , 1.6468611 ,
#        1.7173923 , 1.7838829 , 1.8498654 , 1.9198118 , 1.985256  ,
#        2.056211  , 2.1224303 , 2.1963882 , 2.2619123 , 2.3320975 ,
#        2.3898954 , 2.444803  , 2.4887784 , 2.534986  , 2.574146  ,
#        2.6267283 , 2.676837  , 2.7411394 , 2.7954483 , 2.8584967 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_2[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.25141782, 0.36975425, 0.41692042, 0.4990192 , 0.55027074,
#        0.62558067, 0.67918825, 0.7536222 , 0.81411964, 0.8933144 ,
#        0.964115  , 1.0477813 , 1.1271226 , 1.2089033 , 1.2832441 ,
#        1.3587693 , 1.432331  , 1.5042396 , 1.5778512 , 1.6467566 ,
#        1.7171893 , 1.784264  , 1.8498865 , 1.9202439 , 1.9858558 ,
#        2.0573013 , 2.1233213 , 2.196896  , 2.2619452 , 2.3317058 ,
#        2.3890378 , 2.443643  , 2.4881396 , 2.5344305 , 2.5736885 ,
#        2.6264853 , 2.6765938 , 2.7404592 , 2.7945912 , 2.8575485 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
graph_3[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.2513922 , 0.3697055 , 0.41683996, 0.4989108 , 0.5501276 ,
#        0.6253942 , 0.678939  , 0.7533064 , 0.8137574 , 0.89291686,
#        0.9636942 , 1.0473436 , 1.1266813 , 1.2085185 , 1.2828803 ,
#        1.3585911 , 1.4320631 , 1.5040561 , 1.5777662 , 1.6467131 ,
#        1.7173312 , 1.7846353 , 1.8503218 , 1.9203994 , 1.9864601 ,
#        2.0575986 , 2.1239042 , 2.1977384 , 2.2629986 , 2.333116  ,
#        2.3900788 , 2.4447489 , 2.489189  , 2.535574  , 2.5751667 ,
#        2.6280084 , 2.677543  , 2.7411244 , 2.7951708 , 2.8582447 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_2020[var_name].isel(days=slice(*year_idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.32236844, 0.43781808, 0.48743582, 0.5652386 , 0.608222  ,
#        0.6776481 , 0.7275626 , 0.79886913, 0.8616794 , 0.9409139 ,
#        1.0155302 , 1.0984826 , 1.1813205 , 1.2683961 , 1.3559264 ,
#        1.4450924 , 1.5375359 , 1.6286628 , 1.724917  , 1.8223207 ,
#        1.9239545 , 2.023772  , 2.1228702 , 2.218003  , 2.3058298 ,
#        2.3914878 , 2.4734592 , 2.5534153 , 2.6297946 , 2.7028966 ,
#        2.7752476 , 2.837878  , 2.907547  , 2.9676733 , 3.0353873 ,
#        3.0897593 , 3.1530428 , 3.2020075 , 3.2613773 , 3.3062    ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_1[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.3238551 , 0.43922672, 0.48893455, 0.56655467, 0.6096432 ,
#        0.6791641 , 0.729292  , 0.8007797 , 0.8637272 , 0.94324714,
#        1.0182068 , 1.1017954 , 1.1853092 , 1.2732698 , 1.3617902 ,
#        1.4520891 , 1.5456623 , 1.6380391 , 1.7352988 , 1.8338795 ,
#        1.936425  , 2.0371654 , 2.1368363 , 2.2326505 , 2.3209302 ,
#        2.4070299 , 2.4892275 , 2.5690536 , 2.6450849 , 2.7173786 ,
#        2.7890851 , 2.8508315 , 2.9198246 , 2.978889  , 3.0457442 ,
#        3.0991485 , 3.1617794 , 3.2100248 , 3.2690527 , 3.3135407 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_2[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.32302478, 0.43841118, 0.4881041 , 0.5658386 , 0.6089069 ,
#        0.6784119 , 0.72846764, 0.7998947 , 0.86279523, 0.9422048 ,
#        1.0170289 , 1.1003585 , 1.1835979 , 1.2711959 , 1.3593146 ,
#        1.449153  , 1.5422735 , 1.634145  , 1.7310071 , 1.8291185 ,
#        1.9313102 , 2.0316882 , 2.1311436 , 2.2266932 , 2.3148036 ,
#        2.4007392 , 2.4828565 , 2.5627487 , 2.6389308 , 2.7115576 ,
#        2.7835293 , 2.8456345 , 2.9149063 , 2.9744027 , 3.0416076 ,
#        3.0954025 , 3.1582983 , 3.2068353 , 3.2660027 , 3.3106275 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
wxformer_3[var_name].isel(days=slice(*idx_tuple)).mean('days')
# Out:
# <xarray.DataArray 'T500' (time: 40)> Size: 160B
# array([0.32441637, 0.43978986, 0.48949394, 0.567032  , 0.6101186 ,
#        0.67963535, 0.7297932 , 0.80130583, 0.8642729 , 0.943848  ,
#        1.0188769 , 1.1026022 , 1.1862602 , 1.2744126 , 1.3631436 ,
#        1.4536843 , 1.547492  , 1.640132  , 1.7375947 , 1.8364179 ,
#        1.9391396 , 2.040064  , 2.1398392 , 2.2357857 , 2.3241472 ,
#        2.4103253 , 2.4925582 , 2.5723433 , 2.6482906 , 2.7204065 ,
#        2.7919724 , 2.8535302 , 2.922375  , 2.9812124 , 3.0478835 ,
#        3.1010835 , 3.1635747 , 3.2116675 , 3.2706208 , 3.3150373 ],
#       dtype=float32)
# Dimensions without coordinates: time

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# year_idx_tuple = None, 16
plt.plot(x, graph_2020[var_name].isel(days=slice(*year_idx_tuple)).mean(dim='days').values, label='Graph')
plt.plot(x, graph_1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 1')
plt.plot(x, graph_2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 2')
plt.plot(x, graph_3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# var_name = 'V500'
# idx_tuple = None, None 

plt.plot(x, graph_no_2020[var_name].isel(days=slice(*year_idx_tuple)).mean(dim='days').values, label='Graph no')
plt.plot(x, graph_no1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 1')
plt.plot(x, graph_no2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 2')
plt.plot(x, graph_no3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Graph no noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();

# %%
x = np.arange(1, len(ifs_2020.time) + 1) * 6 

# var_name = 'V500'
# idx_tuple = None, None 

plt.plot(x, wxformer_2020[var_name].isel(days=slice(*year_idx_tuple)).mean(dim='days').values, label='Wxformer')
plt.plot(x, wxformer_1[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 1')
plt.plot(x, wxformer_2[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 2')
plt.plot(x, wxformer_3[var_name].isel(days=slice(*idx_tuple)).mean(dim='days').values, label='Wxformer noise 3')

plt.xlabel('hours')
plt.title(f'{var_name} - RMSE')
# plt.loglog()
plt.legend();
